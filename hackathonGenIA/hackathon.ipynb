# %%
import pandas as pd
import numpy as np
from plotly.subplots import make_subplots
from matplotlib import colors
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
import math
from scipy.stats import pearsonr  # Pour la corrélation Pearson

# %%
df = pd.read_csv(r'data_center\Retail_Prices_of_Products_M.csv', encoding='iso-8859-1', on_bad_lines='skip')

df.info()

df.head(-1).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118482 entries, 0 to 118481
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Year              118482 non-null  int64
#  1   Month             118482 non-null  object
#  2   GEO               118482 non-null  object
#  3   Product Category  118482 non-null  object
#  4   Products          118482 non-null  object
#  5   VALUE             118482 non-null  float64
#  6   Taxable           118482 non-null  object
#  7   Total tax rate    118482 non-null  float64
#  8   Value after tax   118482 non-null  float64
#  9   Essential         118482 non-null  object
#  10  COORDINATE        118482 non-null  float64
#  11  UOM               118482 non-null  object
#  12  QualityScore      118482 non-null  int64
#  13  NormPrice         118482 non-null  float64
#  14  Essential_Bonus   118482 non-null  int64
#  15  Region_Weight     118482 non-null  float64
#  16  Month_Weight      118482 non-null  float64
#  17  Year_Trend        118482 non-null  float64
#  18  Review            118482 non-null  float64
# dtypes: float64(9), int64(3), object(7)
# memory usage: 17.2+ MB
#                                            0       \
# Year                                         2017
# Month                                     January
# GEO                                    Province 1
# Product Category                   Meat & Poultry
# Products          Beef stewing cuts, per kilogram
# VALUE                                       12.66
# Taxable                                        No
# Total tax rate                               11.0
# Value after tax                             12.66
# Essential                               Essential
# COORDINATE                                   11.1
# UOM                                       Dollars
# QualityScore                                    6
# NormPrice                                1.390916
# Essential_Bonus                                 0
# Region_Weight                                 0.2
# Month_Weight                                 -0.2
# Year_Trend                                    0.0
# Review                                        4.6
#
#                                              1       \
# Year                                           2017
# Month                                       January
# GEO                                      Province 1
# Product Category                     Meat & Poultry
# Products          Beef striploin cuts, per kilogram
# VALUE                                         21.94
# Taxable                                          No
# Total tax rate                                 11.0
# Value after tax                               21.94
# Essential                                 Essential
# COORDINATE                                     11.2
# UOM                                         Dollars
# QualityScore                                      9
# NormPrice                                  3.178024
# Essential_Bonus                                   0
# Region_Weight                                   0.2
# Month_Weight                                   -0.2
# Year_Trend                                      0.0
# Review                                          7.0
#
#                                                2       \
# Year                                             2017
# Month                                         January
# GEO                                        Province 1
# Product Category                       Meat & Poultry
# Products          Beef top sirloin cuts, per kilogram
# VALUE                                           13.44
# Taxable                                            No
# Total tax rate                                   11.0
# Value after tax                                 13.44
# Essential                                   Essential
# COORDINATE                                       11.3
# UOM                                           Dollars
# QualityScore                                        7
# NormPrice                                    1.541126
# Essential_Bonus                                     0
# Region_Weight                                     0.2
# Month_Weight                                     -0.2
# Year_Trend                                        0.0
# Review                                            5.4
#
#                                        3                          4       \
# Year                                     2017                       2017
# Month                                 January                    January
# GEO                                Province 1                 Province 1
# Product Category               Meat & Poultry             Meat & Poultry
# Products          Beef rib cuts, per kilogram  Ground beef, per kilogram
# VALUE                                   20.17                       9.12
# Taxable                                    No                         No
# Total tax rate                           11.0                       11.0
# Value after tax                         20.17                       9.12
# Essential                           Essential                  Essential
# COORDINATE                              11.41                       11.4
# UOM                                   Dollars                    Dollars
# QualityScore                                8                          5
# NormPrice                            2.837164                   0.709196
# Essential_Bonus                             0                          0
# Region_Weight                             0.2                        0.2
# Month_Weight                             -0.2                       -0.2
# Year_Trend                                0.0                        0.0
# Review                                    7.6                        3.0
#
#                                         5                            6       \
# Year                                      2017                         2017
# Month                                  January                      January
# GEO                                 Province 1                   Province 1
# Product Category                Meat & Poultry               Meat & Poultry
# Products          Pork loin cuts, per kilogram  Pork rib cuts, per kilogram
# VALUE                                     7.34                         7.37
# Taxable                                     No                           No
# Total tax rate                            11.0                         11.0
# Value after tax                           7.34                         7.37
# Essential                            Essential                    Essential
# COORDINATE                                11.5                         11.6
# UOM                                    Dollars                      Dollars
# QualityScore                                 6                            8
# NormPrice                              0.36641                     0.372188
# Essential_Bonus                              0                            0
# Region_Weight                              0.2                          0.2
# Month_Weight                              -0.2                         -0.2
# Year_Trend                                 0.0                          0.0
# Review                                     3.2                          5.7
#
#                                             7       \
# Year                                          2017
# Month                                      January
# GEO                                     Province 1
# Product Category                    Meat & Poultry
# Products          Pork shoulder cuts, per kilogram
# VALUE                                         4.76
# Taxable                                         No
# Total tax rate                                11.0
# Value after tax                               4.76
# Essential                                Essential
# COORDINATE                                   11.42
# UOM                                        Dollars
# QualityScore                                     6
# NormPrice                                -0.130436
# Essential_Bonus                                  0
# Region_Weight                                  0.2
# Month_Weight                                  -0.2
# Year_Trend                                     0.0
# Review                                         3.6
#
#                                        8                              9       \
# Year                                     2017                           2017
# Month                                 January                        January
# GEO                                Province 1                     Province 1
# Product Category               Meat & Poultry                 Meat & Poultry
# Products          Whole chicken, per kilogram  Chicken breasts, per kilogram
# VALUE                                    5.15                          11.38
# Taxable                                    No                             No
# Total tax rate                           11.0                           11.0
# Value after tax                          5.15                          11.38
# Essential                           Essential                      Essential
# COORDINATE                               11.7                           11.8
# UOM                                   Dollars                        Dollars
# QualityScore                                5                              5
# NormPrice                           -0.055332                       1.144418
# Essential_Bonus                             0                              0
# Region_Weight                             0.2                            0.2
# Month_Weight                             -0.2                           -0.2
# Year_Trend                                0.0                            0.0
# Review                                    2.2                            3.9
#
#                   ...               118471                  118472  \
# Year              ...                 2025                    2025
# Month             ...             February                February
# GEO               ...          Province 11             Province 11
# Product Category  ...  Legumes & Dry Goods   Canned & Jarred Goods
# Products          ...    Hummus, 227 grams  Salsa, 418 millilitres
# VALUE             ...                 3.82                    4.53
# Taxable           ...                   No                     Yes
# Total tax rate    ...                 12.0                    12.0
# Value after tax   ...                 3.82                    5.07
# Essential         ...            Essential           Non-Essential
# COORDINATE        ...               10.103                  10.104
# UOM               ...              Dollars                 Dollars
# QualityScore      ...                    5                       5
# NormPrice         ...            -0.311458               -0.174729
# Essential_Bonus   ...                    0                       1
# Region_Weight     ...                  0.0                     0.0
# Month_Weight      ...                  0.0                     0.0
# Year_Trend        ...                  0.8                     0.8
# Review            ...                  1.8                     4.8
#
#                                         118473  \
# Year                                      2025
# Month                                 February
# GEO                                Province 11
# Product Category               Grains & Bakery
# Products          Pasta sauce, 650 millilitres
# VALUE                                      3.1
# Taxable                                     No
# Total tax rate                            12.0
# Value after tax                            3.1
# Essential                            Essential
# COORDINATE                              10.105
# UOM                                    Dollars
# QualityScore                                 5
# NormPrice                            -0.450113
# Essential_Bonus                              0
# Region_Weight                              0.0
# Month_Weight                               0.0
# Year_Trend                                 0.8
# Review                                     2.3
#
#                                            118474              118475  \
# Year                                         2025                2025
# Month                                    February            February
# GEO                                   Province 11         Province 11
# Product Category            Canned & Jarred Goods       Nuts & Snacks
# Products          Salad dressing, 475 millilitres  Almonds, 200 grams
# VALUE                                        3.44                4.52
# Taxable                                       Yes                  No
# Total tax rate                               12.0                12.0
# Value after tax                              3.85                4.52
# Essential                           Non-Essential       Non-Essential
# COORDINATE                                 10.106              10.107
# UOM                                       Dollars             Dollars
# QualityScore                                    5                   5
# NormPrice                               -0.384637           -0.176655
# Essential_Bonus                                 1                   1
# Region_Weight                                 0.0                 0.0
# Month_Weight                                  0.0                 0.0
# Year_Trend                                    0.8                 0.8
# Review                                        4.4                 5.8
#
#                               118476                       118477  \
# Year                            2025                         2025
# Month                       February                     February
# GEO                      Province 11                  Province 11
# Product Category       Nuts & Snacks                Nuts & Snacks
# Products          Peanuts, 450 grams  Sunflower seeds, 400 grams
# VALUE                           4.05                          4.5
# Taxable                           No                           No
# Total tax rate                  12.0                         12.0
# Value after tax                 4.05                          4.5
# Essential              Non-Essential                Non-Essential
# COORDINATE                    10.108                       10.109
# UOM                          Dollars                      Dollars
# QualityScore                       5                            5
# NormPrice                  -0.267166                    -0.180506
# Essential_Bonus                    1                            1
# Region_Weight                    0.0                          0.0
# Month_Weight                     0.0                          0.0
# Year_Trend                       0.8                          0.8
# Review                           3.5                          4.8
#
#                                  118478                       118479  \
# Year                               2025                         2025
# Month                          February                     February
# GEO                         Province 11                  Province 11
# Product Category  Toiletries & Cleaning        Toiletries & Cleaning
# Products            Deodorant, 85 grams  Toothpaste, 100 millilitres
# VALUE                              8.07                         4.13
# Taxable                             Yes                          Yes
# Total tax rate                     12.0                         12.0
# Value after tax                    9.04                         4.63
# Essential                     Essential                    Essential
# COORDINATE                        10.75                        10.76
# UOM                             Dollars                      Dollars
# QualityScore                          5                            5
# NormPrice                      0.506991                     -0.25176
# Essential_Bonus                       0                            0
# Region_Weight                       0.0                          0.0
# Month_Weight                        0.0                          0.0
# Year_Trend                          0.8                          0.8
# Review                              3.3                          2.0
#
#                                     118480
# Year                                  2025
# Month                             February
# GEO                            Province 11
# Product Category     Toiletries & Cleaning
# Products          Shampoo, 400 millilitres
# VALUE                                 7.18
# Taxable                                Yes
# Total tax rate                        12.0
# Value after tax                       8.04
# Essential                        Essential
# COORDINATE                           10.77
# UOM                                Dollars
# QualityScore                             5
# NormPrice                         0.335598
# Essential_Bonus                          0
# Region_Weight                          0.0
# Month_Weight                           0.0
# Year_Trend                             0.8
# Review                                 5.0
#
# [19 rows x 118481 columns]

# %%
df.drop(['QualityScore', 'NormPrice', 'Essential_Bonus', 'Region_Weight', 'Month_Weight', 'Year_Trend'], axis=1, inplace=True)

# %% [markdown]
# On retire les informations qui nous ont permis de générer les reviews

# %%
df.head().T
# Out:
#                                                 0  \
# Year                                         2017
# Month                                     January
# GEO                                    Province 1
# Product Category                   Meat & Poultry
# Products          Beef stewing cuts, per kilogram
# VALUE                                       12.66
# Taxable                                        No
# Total tax rate                               11.0
# Value after tax                             12.66
# Essential                               Essential
# COORDINATE                                   11.1
# UOM                                       Dollars
# Review                                        4.6
#
#                                                   1  \
# Year                                           2017
# Month                                       January
# GEO                                      Province 1
# Product Category                     Meat & Poultry
# Products          Beef striploin cuts, per kilogram
# VALUE                                         21.94
# Taxable                                          No
# Total tax rate                                 11.0
# Value after tax                               21.94
# Essential                                 Essential
# COORDINATE                                     11.2
# UOM                                         Dollars
# Review                                          7.0
#
#                                                     2  \
# Year                                             2017
# Month                                         January
# GEO                                        Province 1
# Product Category                       Meat & Poultry
# Products          Beef top sirloin cuts, per kilogram
# VALUE                                           13.44
# Taxable                                            No
# Total tax rate                                   11.0
# Value after tax                                 13.44
# Essential                                   Essential
# COORDINATE                                       11.3
# UOM                                           Dollars
# Review                                            5.4
#
#                                             3                          4
# Year                                     2017                       2017
# Month                                 January                    January
# GEO                                Province 1                 Province 1
# Product Category               Meat & Poultry             Meat & Poultry
# Products          Beef rib cuts, per kilogram  Ground beef, per kilogram
# VALUE                                   20.17                       9.12
# Taxable                                    No                         No
# Total tax rate                           11.0                       11.0
# Value after tax                         20.17                       9.12
# Essential                           Essential                  Essential
# COORDINATE                              11.41                       11.4
# UOM                                   Dollars                    Dollars
# Review                                    7.6                        3.0

# %% [markdown]
# +------------------+--------------------------------------------------------------+
# │ Column Name      │ Description                                                  │
# │------------------│--------------------------------------------------------------│
# +------------------+--------------------------------------------------------------+
# │ Year             | Reference Year                                               |
# | Month            | Reference Month                                              │
# │ GEO              │ Geographic region (encoded as Province 1, Province 2, etc.)  │
# │ Products         │ Name of the retail product                                   │
# │ COORDINATE       │ Internal coordinate identifier for product                   │
# │ VALUE            │ Original product price per unit (before tax)                 │
# │ UOM              │ Unit of measure (e.g., Dollars)                              │
# │ Taxable          │ 'Yes' if the product is subject to tax, 'No' otherwise       │
# │ Total tax rate   │ Total tax rate (%) based on province or average for 'Canada' │
# │ Value after tax  │ Price after tax if taxable, else same as VALUE               │
# │ Product Category │ High-level category assigned to the product                  │
# │ Essential        │ 'Essential' for basic needs or 'Non-Essential'               │
# +------------------+--------------------------------------------------------------+

# %%
# Filter out categorical features
df_categorical = df[['Essential', 'Taxable', 'Product Category', 'Products']].astype(str)

# Calculate number of unique values and unique values for each feature
unique_counts = df_categorical.nunique()
unique_values = df_categorical.apply(lambda x: x.unique())

# Create new dataframe with the results
pd.DataFrame({'Number of Unique Values': unique_counts, 'Unique Values': unique_values})
# Out:
#                   Number of Unique Values  \
# Essential                               2
# Taxable                                 2
# Product Category                       13
# Products                              110
#
#                                                       Unique Values
# Essential                                [Essential, Non-Essential]
# Taxable                                                   [No, Yes]
# Product Category  [Meat & Poultry, Dairy & Eggs, Cooking Essenti...
# Products          [Beef stewing cuts, per kilogram, Beef striplo...

# %% [markdown]
# Verification des informations categorielles

# %%
# Filter out numerical features
df_numerical = df.drop(df_categorical.columns, axis=1)

# Generate descriptive statistics
df_numerical.describe().T.round(1)
# Out:
#                     count    mean  std     min     25%     50%     75%     max
# Year             118482.0  2020.6  2.4  2017.0  2019.0  2021.0  2023.0  2025.0
# VALUE            118482.0     5.4  5.2     0.3     2.8     4.0     5.8    48.4
# Total tax rate   118482.0    12.6  2.9     5.0    11.0    13.0    15.0    15.0
# Value after tax  118482.0     5.5  5.2     0.3     2.9     4.0     5.9    48.4
# COORDINATE       118482.0     6.5  3.2     1.1     3.8     6.5     9.2    12.0
# Review           118482.0     3.4  1.4     1.0     2.5     3.2     4.1    10.0

# %%
#Pas de valeur nulle
print(df.isnull().sum())
# Out:
# Year                0
# Month               0
# GEO                 0
# Product Category    0
# Products            0
# VALUE               0
# Taxable             0
# Total tax rate      0
# Value after tax     0
# Essential           0
# COORDINATE          0
# UOM                 0
# Review              0
# dtype: int64

# %%
df.head(-1).T
# Out:
#                                            0       \
# Year                                         2017
# Month                                     January
# GEO                                    Province 1
# Product Category                   Meat & Poultry
# Products          Beef stewing cuts, per kilogram
# VALUE                                       12.66
# Taxable                                        No
# Total tax rate                               11.0
# Value after tax                             12.66
# Essential                               Essential
# COORDINATE                                   11.1
# UOM                                       Dollars
# Review                                        4.6
#
#                                              1       \
# Year                                           2017
# Month                                       January
# GEO                                      Province 1
# Product Category                     Meat & Poultry
# Products          Beef striploin cuts, per kilogram
# VALUE                                         21.94
# Taxable                                          No
# Total tax rate                                 11.0
# Value after tax                               21.94
# Essential                                 Essential
# COORDINATE                                     11.2
# UOM                                         Dollars
# Review                                          7.0
#
#                                                2       \
# Year                                             2017
# Month                                         January
# GEO                                        Province 1
# Product Category                       Meat & Poultry
# Products          Beef top sirloin cuts, per kilogram
# VALUE                                           13.44
# Taxable                                            No
# Total tax rate                                   11.0
# Value after tax                                 13.44
# Essential                                   Essential
# COORDINATE                                       11.3
# UOM                                           Dollars
# Review                                            5.4
#
#                                        3                          4       \
# Year                                     2017                       2017
# Month                                 January                    January
# GEO                                Province 1                 Province 1
# Product Category               Meat & Poultry             Meat & Poultry
# Products          Beef rib cuts, per kilogram  Ground beef, per kilogram
# VALUE                                   20.17                       9.12
# Taxable                                    No                         No
# Total tax rate                           11.0                       11.0
# Value after tax                         20.17                       9.12
# Essential                           Essential                  Essential
# COORDINATE                              11.41                       11.4
# UOM                                   Dollars                    Dollars
# Review                                    7.6                        3.0
#
#                                         5                            6       \
# Year                                      2017                         2017
# Month                                  January                      January
# GEO                                 Province 1                   Province 1
# Product Category                Meat & Poultry               Meat & Poultry
# Products          Pork loin cuts, per kilogram  Pork rib cuts, per kilogram
# VALUE                                     7.34                         7.37
# Taxable                                     No                           No
# Total tax rate                            11.0                         11.0
# Value after tax                           7.34                         7.37
# Essential                            Essential                    Essential
# COORDINATE                                11.5                         11.6
# UOM                                    Dollars                      Dollars
# Review                                     3.2                          5.7
#
#                                             7       \
# Year                                          2017
# Month                                      January
# GEO                                     Province 1
# Product Category                    Meat & Poultry
# Products          Pork shoulder cuts, per kilogram
# VALUE                                         4.76
# Taxable                                         No
# Total tax rate                                11.0
# Value after tax                               4.76
# Essential                                Essential
# COORDINATE                                   11.42
# UOM                                        Dollars
# Review                                         3.6
#
#                                        8                              9       \
# Year                                     2017                           2017
# Month                                 January                        January
# GEO                                Province 1                     Province 1
# Product Category               Meat & Poultry                 Meat & Poultry
# Products          Whole chicken, per kilogram  Chicken breasts, per kilogram
# VALUE                                    5.15                          11.38
# Taxable                                    No                             No
# Total tax rate                           11.0                           11.0
# Value after tax                          5.15                          11.38
# Essential                           Essential                      Essential
# COORDINATE                               11.7                           11.8
# UOM                                   Dollars                        Dollars
# Review                                    2.2                            3.9
#
#                   ...               118471                  118472  \
# Year              ...                 2025                    2025
# Month             ...             February                February
# GEO               ...          Province 11             Province 11
# Product Category  ...  Legumes & Dry Goods   Canned & Jarred Goods
# Products          ...    Hummus, 227 grams  Salsa, 418 millilitres
# VALUE             ...                 3.82                    4.53
# Taxable           ...                   No                     Yes
# Total tax rate    ...                 12.0                    12.0
# Value after tax   ...                 3.82                    5.07
# Essential         ...            Essential           Non-Essential
# COORDINATE        ...               10.103                  10.104
# UOM               ...              Dollars                 Dollars
# Review            ...                  1.8                     4.8
#
#                                         118473  \
# Year                                      2025
# Month                                 February
# GEO                                Province 11
# Product Category               Grains & Bakery
# Products          Pasta sauce, 650 millilitres
# VALUE                                      3.1
# Taxable                                     No
# Total tax rate                            12.0
# Value after tax                            3.1
# Essential                            Essential
# COORDINATE                              10.105
# UOM                                    Dollars
# Review                                     2.3
#
#                                            118474              118475  \
# Year                                         2025                2025
# Month                                    February            February
# GEO                                   Province 11         Province 11
# Product Category            Canned & Jarred Goods       Nuts & Snacks
# Products          Salad dressing, 475 millilitres  Almonds, 200 grams
# VALUE                                        3.44                4.52
# Taxable                                       Yes                  No
# Total tax rate                               12.0                12.0
# Value after tax                              3.85                4.52
# Essential                           Non-Essential       Non-Essential
# COORDINATE                                 10.106              10.107
# UOM                                       Dollars             Dollars
# Review                                        4.4                 5.8
#
#                               118476                       118477  \
# Year                            2025                         2025
# Month                       February                     February
# GEO                      Province 11                  Province 11
# Product Category       Nuts & Snacks                Nuts & Snacks
# Products          Peanuts, 450 grams  Sunflower seeds, 400 grams
# VALUE                           4.05                          4.5
# Taxable                           No                           No
# Total tax rate                  12.0                         12.0
# Value after tax                 4.05                          4.5
# Essential              Non-Essential                Non-Essential
# COORDINATE                    10.108                       10.109
# UOM                          Dollars                      Dollars
# Review                           3.5                          4.8
#
#                                  118478                       118479  \
# Year                               2025                         2025
# Month                          February                     February
# GEO                         Province 11                  Province 11
# Product Category  Toiletries & Cleaning        Toiletries & Cleaning
# Products            Deodorant, 85 grams  Toothpaste, 100 millilitres
# VALUE                              8.07                         4.13
# Taxable                             Yes                          Yes
# Total tax rate                     12.0                         12.0
# Value after tax                    9.04                         4.63
# Essential                     Essential                    Essential
# COORDINATE                        10.75                        10.76
# UOM                             Dollars                      Dollars
# Review                              3.3                          2.0
#
#                                     118480
# Year                                  2025
# Month                             February
# GEO                            Province 11
# Product Category     Toiletries & Cleaning
# Products          Shampoo, 400 millilitres
# VALUE                                 7.18
# Taxable                                Yes
# Total tax rate                        12.0
# Value after tax                       8.04
# Essential                        Essential
# COORDINATE                           10.77
# UOM                                Dollars
# Review                                 5.0
#
# [13 rows x 118481 columns]

# %%
df['Date'] = df['Year'].astype(str) + '-' + df['Month'].astype(str)
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%B', errors='coerce')

# %% [markdown]
# Création d'une nouvelle colonne date format YYYY/MM/DD

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118482 entries, 0 to 118481
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Year              118482 non-null  int64
#  1   Month             118482 non-null  object
#  2   GEO               118482 non-null  object
#  3   Product Category  118482 non-null  object
#  4   Products          118482 non-null  object
#  5   VALUE             118482 non-null  float64
#  6   Taxable           118482 non-null  object
#  7   Total tax rate    118482 non-null  float64
#  8   Value after tax   118482 non-null  float64
#  9   Essential         118482 non-null  object
#  10  COORDINATE        118482 non-null  float64
#  11  UOM               118482 non-null  object
#  12  Review            118482 non-null  float64
#  13  Date              118482 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(1), object(7)
# memory usage: 12.7+ MB

# %%
fig = make_subplots(rows=2, cols=2, specs=[[{'type':'domain'}]*2]*2, vertical_spacing=0.05, horizontal_spacing=0.01)


for i, feature in enumerate(df_categorical.columns):
    value_counts = df_categorical[feature].value_counts()
    labels = value_counts.index.tolist()
    values = value_counts.values.tolist()

    cmap = colors.LinearSegmentedColormap.from_list("orangered", ["orangered", "white"])
    norm = colors.Normalize(vmin=0, vmax=len(labels))
    color_list = [colors.rgb2hex(cmap(norm(i))) for i in range(len(labels))]

    pie_chart = go.Pie(
        labels=labels,
        values=values,
        hole=0.6,
        marker=dict(colors=color_list, line=dict(color='white', width=3)),
        textposition='inside',
        textinfo='percent+label',
        title=feature, 
        title_font=dict(size=25, color='black', family='Calibri')
    )

    if i < 4:
        row = i // 2 + 1
        col = i % 2 + 1
        fig.add_trace(pie_chart, row=row, col=col)

# Update the layout
fig.update_layout(showlegend=False, height=1000, width=980, 
                   title={
                          'text':"Distribution of Categorical Variables",
                          'y':0.95,
                          'x':0.5,
                          'xanchor':'center',
                          'yanchor':'top',
                          'font': {'size':28, 'color':'black', 'family':'Calibri'}
                         })

# Show the plot
fig.show()

# %% [markdown]
# Visualisation des différents des types de catégories essentielles.
# On trouve bizarre que 87,7% des produits sont non taxable
# On observe que 82,7% sont des produits essentiels.
#
# En passant la souris vous pouvez voir de façon précise les informations.

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(18, 8))

sns.boxplot(
    data=df,
    x="Product Category",
    y="VALUE",
    hue="Product Category",
    palette="hls",
    dodge=False,
    legend=True
)

plt.xticks(rotation=45, ha='right')
plt.title("Distribution of Product Prices by Category (Before Tax)", fontsize=16)
plt.xlabel("Product Category", fontsize=12)
plt.ylabel("Product Price ($)", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# Dispersions des différentes catégories des produits, on observe une grosse dispersion sur Infant & Baby Products et un peu moins sur Meat & Poultry.
#
# On peut supposer une grosse évolution dans le temps de Infant & Baby Products de part sa dispersion.

# %%
plt.figure(figsize=(16, 5))
df["Product Category"].value_counts().plot(kind="bar", color="steelblue")
plt.title("Number of Products per Category", fontsize=16, fontweight='bold')
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# En terme de quantité on observe que les Légumes, viandes et Fruits représentent la majorité des produits (en quantité).
# Prenons pour la suite de l'étude les Légumes.

# %%
# Création d'une table croisée
cross_tab = pd.crosstab(df['Taxable'], df['Essential'], normalize='index') * 100

cross_tab.plot(kind='bar', stacked=True, color=['green', 'orange'])

plt.title('Proportion de produits essentiels vs non essentiels selon la taxabilité')
plt.xlabel('Taxable')
plt.ylabel('Proportion (%)')
plt.legend(title='Essential')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# On observe que la proportion des produits essentiels sont majoritairement non taxé.

# %%
# Agrégation des données par produit et statut essentiel
grouped = df.groupby(['Products', 'Essential']).agg({
    'Review': 'mean',
    'Value after tax': 'sum'
}).reset_index()

# Création du graphique
plt.figure(figsize=(16, 10))
sns.scatterplot(
    data=grouped,
    x='Products',
    y='Review',
    size='Value after tax',
    hue='Essential',
    sizes=(100, 2000),
    alpha=0.7,
    edgecolor='black'
)

plt.title('Niveau moyen de review par produit (Essentiel vs Non essentiel)')
plt.xticks(rotation=90)
plt.xlabel('Produits')
plt.ylabel('Review moyen')
plt.tight_layout()
plt.legend(title='Essential', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# Visualisation des différents produits en fonction des evaluations (reviews) par rapport à ce qui est essentiel oju non

# %%
# Agrégation des données par produit et statut essentiel
grouped = df.groupby(['Product Category', 'Essential']).agg({
    'Review': 'mean',
    'Value after tax': 'sum'
}).reset_index()

# Création du graphique
plt.figure(figsize=(16, 10))
sns.scatterplot(
    data=grouped,
    x='Product Category',
    y='Review',
    size='Value after tax',
    hue='Essential',
    sizes=(100, 2000),
    alpha=0.6,
    edgecolor='black'
)

plt.title('Niveau moyen de review par produit (Essentiel vs Non essentiel)')
plt.xticks(rotation=90)
plt.xlabel('Product Category')
plt.ylabel('Review moyen')
plt.tight_layout()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# Observation par product category : on observe que les Beverages (boissons), les surgellés (Frozen Food) et les snacks sont totalements non essentiels

# %%
plt.figure(figsize=(12, 6))
order = df.groupby('GEO')['Total tax rate'].mean().sort_values().index
sns.barplot(x='GEO', y='Total tax rate', hue='GEO', data=df, palette='Set2', legend=False)
# Out:
# <Axes: xlabel='GEO', ylabel='Total tax rate'>

# %% [markdown]
# Evaluation des taxes par provinces

# %%
# Regrouper par Date et GEO, puis moyenne de la taxe
tax_trend = df.groupby(['Date', 'GEO'])['Total tax rate'].mean().reset_index()

# Tracé
plt.figure(figsize=(14, 8))
sns.lineplot(data=tax_trend, x='Date', y='Total tax rate', hue='GEO')
plt.title("Évolution du taux de taxe par province")
plt.xlabel("Date")
plt.ylabel("Taux de taxe (%)")
plt.legend(title='Province', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Pas de modification des taxes en fonction du temps

# %%
nb_taxable_rows = df[df['Taxable'] == 'Yes'].shape[0]
print(f"Nombre total de lignes taxables : {nb_taxable_rows}")

nb_taxable_products = df[df['Taxable'] == 'Yes']['Products'].nunique()
print(f"Nombre de produits distincts taxables : {nb_taxable_products}")
# Out:
# Nombre total de lignes taxables : 15092
# Nombre de produits distincts taxables : 14

# %% [markdown]
# Peu de produits réellement taxé

# %%
# Filtrer les produits taxables
df_taxable = df[df['Taxable'] == 'Yes']

# Compter le nombre de produits DISTINCTS taxables qui sont essentiels ou non
essential_counts = df_taxable.groupby('Essential')['Products'].nunique()

print("Nombre de produits DISTINCTS taxables par statut 'Essential':")
print(essential_counts)
# Out:
# Nombre de produits DISTINCTS taxables par statut 'Essential':
# Essential
# Essential        8
# Non-Essential    6
# Name: Products, dtype: int64

# %% [markdown]
# Voici la proportion entre les produits taxable ou non

# %%
df['TaxCollected'] = df['Value after tax'] - df['VALUE']

# Filtrer les produits taxables
df_taxable = df[df['Taxable'] == 'Yes']

# Regrouper par province et produit
grouped_taxable = df_taxable.groupby(['GEO', 'Products'])['TaxCollected'].sum().reset_index()

# Top 10 produits les plus taxés (au total)
top_products = grouped_taxable.groupby('Products')['TaxCollected'].sum().nlargest(10).index

# Filtrer les lignes correspondantes
filtered_taxable = grouped_taxable[grouped_taxable['Products'].isin(top_products)]

# Tracer
plt.figure(figsize=(16, 8))
sns.barplot(data=filtered_taxable, x='Products', y='TaxCollected', hue='GEO')
plt.xticks(rotation=45, ha='right')
plt.title("Taxes collectées par produit et par province (produits taxables uniquement)")
plt.xlabel("Produit")
plt.ylabel("Montant de taxe collectée")
plt.legend(title='Province', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Voici une visualisation des 10 produits taxés (Value after tax - VALUE)

# %%
# Top 5 provinces par taxe totale
top_provinces = df.groupby('GEO')['TaxCollected'].sum().nlargest(5).index

# Filtrer DataFrame pour ne garder que ces provinces
df_top = df[df['GEO'].isin(top_provinces)]

# Regrouper pour analyse par province et produit
grouped_top_prov = df_top.groupby(['GEO', 'Products'])['TaxCollected'].sum().reset_index()

# %%
pivot = grouped_top_prov.pivot(index='GEO', columns='Products', values='TaxCollected').fillna(0)

# Heatmap
plt.figure(figsize=(18, 8))
sns.heatmap(pivot, cmap='YlOrRd', linewidths=0.5)
plt.title("Montant de taxes collectées par produit et par province (Top 11 provinces)")
plt.xlabel("Produit")
plt.ylabel("Province")
plt.tight_layout()
plt.show()

# %% [markdown]
# On trouve bizarre qu'il n'y ai QUE 14 produits taxable (probleme de dataset??) mais on voit bien que ceux-ci touche plus les produits de bébé

# %%
import plotly.express as px

# Treemap avec province et produit imbriqués
fig = px.treemap(grouped_top_prov,
                 path=['GEO', 'Products'],
                 values='TaxCollected',
                 title="Répartition des taxes collectées par province et produit (Top 5 provinces)")
fig.show()

# %% [markdown]
# Autre façon de voir cecic en passant la souris.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118482 entries, 0 to 118481
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Year              118482 non-null  int64
#  1   Month             118482 non-null  object
#  2   GEO               118482 non-null  object
#  3   Product Category  118482 non-null  object
#  4   Products          118482 non-null  object
#  5   VALUE             118482 non-null  float64
#  6   Taxable           118482 non-null  object
#  7   Total tax rate    118482 non-null  float64
#  8   Value after tax   118482 non-null  float64
#  9   Essential         118482 non-null  object
#  10  COORDINATE        118482 non-null  float64
#  11  UOM               118482 non-null  object
#  12  Review            118482 non-null  float64
#  13  Date              118482 non-null  datetime64[ns]
#  14  TaxCollected      118482 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(7)
# memory usage: 13.6+ MB
# None

# %%
plt.figure(figsize=(12, 5))
yearly_avg = df.groupby("Date")["VALUE"].mean().reset_index()
sns.lineplot(data=yearly_avg, x="Date", y="VALUE", marker="o", color="teal")
plt.title("Yearly Trend of Average Retail Prices", fontsize=16, fontweight='bold')
plt.xlabel("Year")
plt.ylabel("Average Price ($)")
plt.grid(True)
plt.show()

# %% [markdown]
# Visualisation de l'évolution des prix moyen au cours du temps, on observe une hauss tendanciel avec une augmentetion entre 2020-2025

# %%
df_vegetables = df[df['Product Category'].str.contains('Vegetables', case=False, na=False)].copy()

# Regrouper par date et calculer le prix moyen
df_veg_grouped = df_vegetables.groupby('Date')['VALUE'].mean().reset_index()

plt.figure(figsize=(10, 5))
sns.lineplot(data=df_veg_grouped, x='Date', y='VALUE', marker='o', color='green')

plt.title("Évolution du prix moyen des produits 'Vegetables'")
plt.xlabel("Date")
plt.ylabel("Prix moyen (VALUE)")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# On observe une évolution du prix des légumes au cours du temps.

# %%
df_vegetables = df[df['Product Category'].str.contains('Vegetables', case=False, na=False)].copy()

df_veg_grouped = (
    df_vegetables
    .groupby(['Date', 'Products'])[['VALUE', 'Review']]
    .mean()
    .reset_index()
)
df_veg_grouped = df_veg_grouped[
    ~df_veg_grouped['Products'].str.contains('Canned|Frozen', case=False, na=False)
]

plt.figure(figsize=(12, 6))

# Courbe par type de légumes
sns.lineplot(data=df_veg_grouped, x='Date', y='VALUE', hue='Products', marker='o')

plt.title("Évolution du prix moyen des différents produits 'Vegetables'")
plt.xlabel("Date")
plt.ylabel("Prix moyen (VALUE)")
plt.xticks(rotation=45)
plt.legend(title="Produit")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Difficile à lire, on retire le surgellé et les conserve car on veut la saisonnalité.

# %%
products = df_veg_grouped['Products'].unique()
n = len(products)

if n == 0:
    print("Aucun produit 'Vegetables' hors 'Canned' ou 'Frozen' trouvé.")
else:
    df_grouped = df_vegetables.groupby(['Date', 'Products'])[['VALUE', 'Review']].mean().reset_index()

    cols = 3
    rows = math.ceil(n / cols)
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 4), sharex=True)
    axes = axes.flatten()

    for i, product in enumerate(products):
        ax = axes[i]
        data = df_grouped[df_grouped['Products'] == product].dropna(subset=['VALUE', 'Review'])

        sns.lineplot(data=data, x='Date', y='VALUE', ax=ax, label='Prix moyen', color='blue')
        sns.lineplot(data=data, x='Date', y='Review', ax=ax, label='Review', color='orange')

        # Calcul corrélation Pearson
        if len(data) > 1:
            corr, _ = pearsonr(data['VALUE'], data['Review'])
            corr_text = f"Corrélation Pearson : {corr:.2f}"
        else:
            corr_text = "Corrélation Pearson : N/A"

        # Affichage de la corrélation dans le coin supérieur droit
        ax.text(0.95, 0.9, corr_text, transform=ax.transAxes,
                horizontalalignment='right', fontsize=9,
                bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray'))

        ax.set_title(product, fontsize=10)
        ax.set_xlabel('')
        ax.set_ylabel('Prix moyen / Review')

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.suptitle("Évolution du prix moyen – Produits 'Vegetables / Reviews'", fontsize=14)
    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %% [markdown]
# On observe une saisonnalité entre les différents légumes (après filtre), on voit bien le changement de saison lié au filtre.
# De plus on voit bien les corrélation entre des review entre les différentes courbes.
# SAUF pour les comcombres, apparement les canadiens adorent les comcombre.
#
# Par contre qu'est qui est importer par le Canada ou non, on devrait le vérifier

# %%
df_numerical.info()
df_correlation = df_numerical[['Year', 'VALUE', 'Total tax rate', 'Value after tax', 'Review']]
df_correlation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118482 entries, 0 to 118481
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             118482 non-null  int64
#  1   Month            118482 non-null  object
#  2   GEO              118482 non-null  object
#  3   VALUE            118482 non-null  float64
#  4   Total tax rate   118482 non-null  float64
#  5   Value after tax  118482 non-null  float64
#  6   COORDINATE       118482 non-null  float64
#  7   UOM              118482 non-null  object
#  8   Review           118482 non-null  float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 8.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118482 entries, 0 to 118481
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             118482 non-null  int64
#  1   VALUE            118482 non-null  float64
#  2   Total tax rate   118482 non-null  float64
#  3   Value after tax  118482 non-null  float64
#  4   Review           118482 non-null  float64
# dtypes: float64(4), int64(1)
# memory usage: 4.5 MB

# %%
# Define a colormap
orangered_cmap = LinearSegmentedColormap.from_list('orangered', ['#FFECEC','orangered'])

# Calculation of the Spearman correlation
target = 'Value after tax'
df_ordered = pd.concat([df_correlation.drop(target,axis=1), df_correlation[target]],axis=1)
corr = df_ordered.corr()

# Create a mask so that we see the correlation values only once
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask,1)] = True

# Plot the heatmap correlation
plt.figure(figsize=(18,12))
sns.heatmap(corr, mask=mask, annot=True, cmap=orangered_cmap, fmt='.2f', linewidths=0.2)
plt.show()

# %% [markdown]
# On observe une forte correlation entre les review et la VALUE. Donc correlation entre le prix et la qualité (tnormal on l'a codé comme ça)

# %%
plt.figure(figsize=(14, 6))

# Moyenne par date et catégorie
df_grouped = df.groupby(['Date', 'Product Category'])['VALUE'].mean().reset_index()

# Tracer les courbes
sns.lineplot(data=df_grouped, x='Date', y='VALUE', hue='Product Category', palette='tab10')

# Ajouter une étiquette à la fin de chaque courbe
last_points = df_grouped.sort_values('Date').groupby('Product Category').tail(1)

for _, row in last_points.iterrows():
    plt.text(
        row['Date'], row['VALUE'],               # position x, y
        row['Product Category'],                 # texte
        fontsize=10, fontweight='bold',
        va='center', ha='left',
        color='black'
    )

# Mise en forme
plt.title("Average Product Price Trends by Category Over Years", fontsize=16, fontweight='bold')
plt.xlabel("Year")
plt.ylabel("Average Price ($)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# On observe une grosse evolution des prix sur Infant & Baby Product et Cooking Essentials (Facteur d'importations, transport??)

# %%
# 1. Calcul du prix moyen par produit
top10_products = df.groupby('Products')['VALUE'].mean().sort_values(ascending=False).head(10).index

# 2. Filtrer le DataFrame pour ces produits
df_top10 = df[df['Products'].isin(top10_products)].copy()

# 4. Calculer la moyenne des reviews par produit et date
df_reviews = df_top10.groupby(['Date', 'Products'])['Review'].mean().reset_index()

# 5. Tracer l'évolution
plt.figure(figsize=(16, 8))
sns.lineplot(data=df_reviews, x='Date', y='Review', hue='Products', palette='tab10')
plt.title("Évolution des avis pour les 10 produits les plus chers", fontsize=16, fontweight='bold')
plt.xlabel("Date")
plt.ylabel("Note moyenne (Review)")
plt.legend(title="Produit", bbox_to_anchor=(1.02, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# On observe une évolution des prix, on va lisser les courbes.

# %%
# 1. Calcul des 10 produits les plus chers
top10_products = df.groupby('Products')['VALUE'].mean().sort_values(ascending=False).head(10).index

# 2. Filtrage du DataFrame
df_top10 = df[df['Products'].isin(top10_products)].copy()

# 4. Calcul de la moyenne des reviews par produit et par date
df_reviews = df_top10.groupby(['Date', 'Products'])['Review'].mean().reset_index()

# 5. Tri pour le rolling
df_reviews = df_reviews.sort_values(by=['Products', 'Date'])

# 6. Lissage avec moyenne mobile (fenêtre = 3)
df_reviews['Review_smoothed'] = df_reviews.groupby('Products')['Review'].transform(lambda x: x.rolling(window=3, min_periods=1).mean())

# 7. Tracé du graphique
plt.figure(figsize=(16, 8))
sns.lineplot(data=df_reviews, x='Date', y='Review_smoothed', hue='Products', palette='tab10')
plt.title("Évolution lissée des avis pour les 10 produits les plus chers", fontsize=16, fontweight='bold')
plt.xlabel("Date")
plt.ylabel("Note moyenne lissée")
plt.legend(title="Produit", bbox_to_anchor=(1.02, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Le prix des produits augmente avec le temps et suivent la note moyenne lissé

# %%
# 1. Calcul des 10 produits les moins chers
top10_cheap_products = df.groupby('Products')['VALUE'].mean().sort_values(ascending=True).head(10).index

# 2. Filtrage du DataFrame
df_cheap = df[df['Products'].isin(top10_cheap_products)].copy()

# 3. S'assurer que 'Date' est bien au format datetime
df_cheap['Date'] = pd.to_datetime(df_cheap['Date'])

# 4. Calcul de la moyenne des reviews par produit et par date
df_reviews_cheap = df_cheap.groupby(['Date', 'Products'])['Review'].mean().reset_index()

# 5. Tri pour le rolling
df_reviews_cheap = df_reviews_cheap.sort_values(by=['Products', 'Date'])

# 6. Lissage avec moyenne mobile (fenêtre = 3)
df_reviews_cheap['Review_smoothed'] = df_reviews_cheap.groupby('Products')['Review'].transform(lambda x: x.rolling(window=3, min_periods=1).mean())

# 7. Tracé du graphique
plt.figure(figsize=(16, 8))
sns.lineplot(data=df_reviews_cheap, x='Date', y='Review_smoothed', hue='Products', palette='tab10')
plt.title("Évolution lissée des avis pour les 10 produits les moins chers", fontsize=16, fontweight='bold')
plt.xlabel("Date")
plt.ylabel("Note moyenne lissée")
plt.legend(title="Produit", bbox_to_anchor=(1.02, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Idem que pour les 10 plus cher

# %%
df_cheap = df[df['Products'].isin(top10_cheap_products)].copy()


# Calcul des corrélations par produit
correlations = []
for product in top10_cheap_products:
    df_product = df_cheap[df_cheap['Products'] == product]
    
    # Regrouper par date pour aligner les valeurs
    grouped = df_product.groupby('Date')[['VALUE', 'Review']].mean().dropna()

    if len(grouped) > 1:  # Nécessaire pour calculer une corrélation
        corr = grouped['VALUE'].corr(grouped['Review'])
        if pd.notna(corr):
            correlations.append(corr)

# Moyenne des corrélations
mean_correlation = sum(correlations) / len(correlations)
print(f"Moyenne des corrélations VALUE vs Review pour les 10 produits les moins chers : {mean_correlation:.3f}")
# Out:
# Moyenne des corrélations VALUE vs Review pour les 10 produits les moins chers : 0.570

# %%
df_cheap = df[df['Products'].isin(top10_products)].copy()


# Calcul des corrélations par produit
correlations = []
for product in top10_products:
    df_product = df_cheap[df_cheap['Products'] == product]
    
    # Regrouper par date pour aligner les valeurs
    grouped = df_product.groupby('Date')[['VALUE', 'Review']].mean().dropna()

    if len(grouped) > 1:  # Nécessaire pour calculer une corrélation
        corr = grouped['VALUE'].corr(grouped['Review'])
        if pd.notna(corr):
            correlations.append(corr)

# Moyenne des corrélations
mean_correlation = sum(correlations) / len(correlations)
print(f"Moyenne des corrélations VALUE vs Review pour les 10 produits les plus chers : {mean_correlation:.3f}")
# Out:
# Moyenne des corrélations VALUE vs Review pour les 10 produits les plus chers : 0.869

# %% [markdown]
# Cela confirme nos doute sur la corrélation.

# %%
# 1. Compter les produits par catégorie
count_per_category = df["Product Category"].value_counts()

# 2. Moyenne du prix après taxe par catégorie
avg_price_per_category = df.groupby("Product Category")["Value after tax"].mean()

# 3. Fusionner les deux dans un DataFrame
summary_df = pd.DataFrame({
    "Product Count": count_per_category,
    "Avg Price After Tax": avg_price_per_category
}).dropna()

# 4. Trier par nombre de produits
summary_df = summary_df.sort_values("Product Count", ascending=False)

# 5. Création du graphique
fig, ax1 = plt.subplots(figsize=(18, 6))

x = summary_df.index
x_pos = range(len(x))

# Axe Y gauche : Count
color1 = 'steelblue'
ax1.set_xlabel('Product Category')
ax1.set_ylabel('Product Count', color=color1)
ax1.bar(x_pos, summary_df['Product Count'], color=color1, width=0.4, align='center', label="Product Count")
ax1.tick_params(axis='y', labelcolor=color1)

# Axe Y droit : Prix moyen
ax2 = ax1.twinx()  # instanciation du second axe Y
color2 = 'salmon'
ax2.set_ylabel('Avg Price After Tax ($)', color=color2)
ax2.plot(x_pos, summary_df['Avg Price After Tax'], color=color2, marker='o', label="Avg Price After Tax")
ax2.tick_params(axis='y', labelcolor=color2)

# X ticks
plt.xticks(ticks=x_pos, labels=x, rotation=45, ha='right')

# Titre et mise en page
plt.title("Product Count vs Avg Price After Tax by Category", fontsize=16, fontweight='bold')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# Nous avons cherché à visualiser sur un même graphe et par catégorie les volumes de vente et le prix moyen, ceci afin d'identifier les catégories à plus fort enjeu volumes et CA (et possiblement marges).
